# %%
import numpy as np 
from functions import *
import matplotlib.pyplot as plt

# %%
d = 2
L = 12
boundary = "periodic"
C =  create_heisenberg_state(L, boundary=boundary)
# Out:
# E/N= -0.44894924312043344

# %%
Tree1, Indices1, sigma_temp1 = make_tree(d, L, C, mps=False)
simple_tree1 = simplify_tree(Tree1, Indices1, sigma_temp1)
result1 = sorted(graph_entropy(simple_tree1, C, d, L))[::-1]
print(sum(result1))
print(result1)
graph_with_entropy(simple_tree1, C, d, L)
# Out:
# 14.161325218565974
# [1.7084737195997055, 1.6915081009627533, 1.6915081009627484, 1.6379181817660942, 1.637918181766093, 1.5372737598213628, 1.5372737598213626, 1.3597257069329276, 1.3597257069329276]

# %%
a = min_info(L, boundary)
simple_tree_m = a.make_tree()
result_m = sorted(graph_with_entropy(simple_tree_m, C, d, L))[::-1]
print(sum(result1))
print(result1)
graph_with_entropy(simple_tree_m, C, d, L)
# Out:
# 14.161325218565974
# [1.7084737195997055, 1.6915081009627533, 1.6915081009627484, 1.6379181817660942, 1.637918181766093, 1.5372737598213628, 1.5372737598213626, 1.3597257069329276, 1.3597257069329276]

# %%
Tree2, Indices2, sigma_temp2 = make_tree(d, L, C, mps=True)
simple_tree2 = simplify_tree(Tree2, Indices2, sigma_temp2)
result2 = sorted(graph_entropy(simple_tree2, C, d, L))[::-1]
print(sum(result2))
print(result2)
graph_with_entropy(simple_tree2, C, d, L).render("periodic_mps")
# Out:
# 7.147581078463828
# [1.5165117973436715, 1.4768253458925917, 1.4768253458925913, 1.3387092946674861, 1.3387092946674861]
# 'periodic_mps.pdf'

# %%
trees = remove_tree(tree_dict(L)[L])

# %%
bond = []
for tree in trees:
    bond.append(np.sum(graph_entropy(tree, C, d, L)))
plt.hist(bond, bins = 30)
plt.xlabel("Sum of entropy")
plt.ylabel("Frequency")
plt.savefig("sum_entropy_open_N8.png")

# %%
bond2 = []
for tree in trees:
    bond2.append(max(graph_entropy(tree, C, d, L)))
plt.hist(bond2, bins = 20)
plt.xlabel("Max entropy")
plt.ylabel("Frequency")
plt.savefig("max_entropy_open_N8.png")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f69d5aa45fbd> in <module>
#       1 bond2 = []
#       2 for tree in trees:
# ----> 3     bond2.append(max(graph_entropy(tree, C, d, L)))
#       4 plt.hist(bond2, bins = 20)
#       5 plt.xlabel("Max entropy")
#
# ~/Desktop/OneDrive/tree/functions.py in graph_entropy(tree, C, d, L)
#     121             else:
#     122                 l = all_spins(find_node_by_id(node["id"], tree), tree)
# --> 123                 S.append(bond_entropy(l, l_all, C, d, L))
#     124     return S
#     125 def graph_with_entropy(tree, C, d, L):
#
# ~/Desktop/OneDrive/tree/functions.py in bond_entropy(l, l_all, C, d, L)
#      99     Ct = Ct.reshape(d**len(l), -1)
#     100     rho = Ct@np.transpose(Ct) if Ct.shape[0] < Ct.shape[1] else np.transpose(Ct)@Ct
# --> 101     return entropy(rho)
#     102 def get_root(tree):
#     103     for node in tree:
#
# ~/Desktop/OneDrive/tree/functions.py in entropy(rho)
#      91     w, v = eigh(rho)
#      92     w = np.maximum(w, 0)
# ---> 93     assert np.abs(np.sum(w)-1) < 10**-10
#      94     return spss.entropy(w, base=2)
#      95 def bond_entropy(l, l_all, C, d, L):
#
# /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    2074
#    2075     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2076                           initial=initial)
#    2077
#    2078
#
# /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      68
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      72
#
# /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in <dictcomp>(.0)
#      68
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      72
#
# KeyboardInterrupt:

# %%
min_sum = 10
for tree in trees:
    if np.sum(graph_entropy(tree, C, d, L)) < min_sum:
        min_sum = np.sum(graph_entropy(tree, C, d, L))
        min_tree = tree
r = sorted(graph_entropy(min_tree, C, d, L))[::-1]
print(sum(r))
print(r)
# Out:
# 6.871348976013614
# [1.5165117973436686, 1.338709294667488, 1.3387092946674863, 1.3387092946674857, 1.3387092946674852]

# %%
min_max = 10
for tree in trees:
    if max(graph_entropy(tree, C, d, L)) < min_max:
        min_max = max(graph_entropy(tree, C, d, L))
        min_tree = tree
r = sorted(graph_entropy(min_tree, C, d, L))[::-1]
print(sum(r))
print(r)
# Out:
# 6.9697785757876405
# [1.4768253458925904, 1.4768253458925904, 1.338709294667487, 1.3387092946674863, 1.3387092946674857]
